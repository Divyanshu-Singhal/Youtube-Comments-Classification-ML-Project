# %% [markdown]
# # **Team Members :**
#
#
# *   **Bhut Ayush Dilipbhai (B21CS016)**
#
# *   **Jaysukh Makvana (B21CS043)**
# *   **Divyanshu Singhal (B21CS025)**

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
#importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#to read dataset
data = pd.read_csv("/content/drive/MyDrive/YT_Videos_Comments.csv")
data
# Out:
#                 User                                 Video Title  \
# 0         Cleo Abram        Robots made of spiders (yes, really)
# 1         Cleo Abram        Robots made of spiders (yes, really)
# 2         Cleo Abram        Robots made of spiders (yes, really)
# 3         Cleo Abram        Robots made of spiders (yes, really)
# 4         Cleo Abram        Robots made of spiders (yes, really)
# ...              ...                                         ...
# 861957  Physics Girl  5 AMAZING stars we’ve discovered in space!
# 861958  Physics Girl  5 AMAZING stars we’ve discovered in space!
# 861959  Physics Girl  5 AMAZING stars we’ve discovered in space!
# 861960  Physics Girl  5 AMAZING stars we’ve discovered in space!
# 861961  Physics Girl  5 AMAZING stars we’ve discovered in space!
#
#                                         Video Description     Video ID  \
# 0       I'M SORRY OK. But this is fascinating. \n\nSci...  YXd4z3gWyVE
# 1       I'M SORRY OK. But this is fascinating. \n\nSci...  YXd4z3gWyVE
# 2       I'M SORRY OK. But this is fascinating. \n\nSci...  YXd4z3gWyVE
# 3       I'M SORRY OK. But this is fascinating. \n\nSci...  YXd4z3gWyVE
# 4       I'M SORRY OK. But this is fascinating. \n\nSci...  YXd4z3gWyVE
# ...                                                   ...          ...
# 861957  This episode is brought to you by Squarespace:...  xyXpQxz7BOs
# 861958  This episode is brought to you by Squarespace:...  xyXpQxz7BOs
# 861959  This episode is brought to you by Squarespace:...  xyXpQxz7BOs
# 861960  This episode is brought to you by Squarespace:...  xyXpQxz7BOs
# 861961  This episode is brought to you by Squarespace:...  xyXpQxz7BOs
#
#                                       Comment (Displayed)  \
# 0       zombie spider!! bomb the damn lab before it&#3...
# 1       This is way less cool than it seems, spiders a...
# 2       Spiders see this and this is why they made the...
# 3                                      you looks pretty 😍
# 4       I can hear the hairs standing up on my wife’s ...
# ...                                                   ...
# 861957  hey girl,make more vdos and make it lengthy .....
# 861958                                              Third
# 861959                                              third
# 861960                                             Second
# 861961                                              first
#
#                                          Comment (Actual)  \
# 0       zombie spider!! bomb the damn lab before it's ...
# 1       This is way less cool than it seems, spiders a...
# 2       Spiders see this and this is why they made the...
# 3                                      you looks pretty 😍
# 4       I can hear the hairs standing up on my wife’s ...
# ...                                                   ...
# 861957  hey girl,make more vdos and make it lengthy .....
# 861958                                              Third
# 861959                                              third
# 861960                                             Second
# 861961                                              first
#
#              Comment Author Comment Author Channel ID          Comment Time
# 0              Bagus Hutomo  UC-F6GFyxAqGhN3_MEJLksxg  2023-03-11T07:39:33Z
# 1                   CMZ neu  UCZKnVEtNze-fFxCvsRnaIuA  2023-03-11T05:26:10Z
# 2             Kiana Marrie   UCutp6oeKAxsO6fXp1vyzvIQ  2023-03-11T04:02:27Z
# 3                      Noob  UC9J99riIPd6ja-XDFSwrY-Q  2023-03-11T02:50:50Z
# 4            chancellor9000  UC8WEPXkCSh87h6kBcFT-o1g  2023-03-11T02:46:02Z
# ...                     ...                       ...                   ...
# 861957       Omkar Bhambure  UCgY0dubqhFHVD6wWq37UCtg  2016-01-12T21:32:52Z
# 861958         Izzo Mapping  UCF0vKXNgNwO2iutasiiLoNQ  2016-01-12T21:30:37Z
# 861959           Indecisive  UChNeyv6tBcgrjfXJiy3xRFg  2016-01-12T21:30:34Z
# 861960               Nathan  UCkMeQzamGWna00H_sMQddvQ  2016-01-12T21:30:02Z
# 861961  The Physicist Cuber  UCnpO0ObncSaFW2fKSAp-OrA  2016-01-12T21:29:47Z
#
# [861962 rows x 9 columns]

# %%
data.dtypes
# Out:
# User                         object
# Video Title                  object
# Video Description            object
# Video ID                     object
# Comment (Displayed)          object
# Comment (Actual)             object
# Comment Author               object
# Comment Author Channel ID    object
# Comment Time                 object
# dtype: object

# %%
data.isnull().sum()
# Out:
# User                              0
# Video Title                     149
# Video Description            196767
# Video ID                     429330
# Comment (Displayed)          467375
# Comment (Actual)             482881
# Comment Author               482909
# Comment Author Channel ID    482868
# Comment Time                 482862
# dtype: int64

# %%
#Ratio of Null values in dataset
if data.isnull().sum().sum() != 0:
  na_df = (data.isnull().sum() / len(data)) * 100
  na_df = na_df.drop(na_df[na_df == 0].index).sort_values(ascending=False)
  missing_data = pd.DataFrame({'Missing Ratio %' :na_df})
  missing_data.plot(kind = "barh")
  plt.show()
else:
  print('No Null Values found')

# %%
data= data.drop(["Video Title","Video Description","Comment (Displayed)","Comment Author","Comment Time","Comment Author Channel ID"],axis=1)
data
# Out:
#                 User     Video ID  \
# 0         Cleo Abram  YXd4z3gWyVE
# 1         Cleo Abram  YXd4z3gWyVE
# 2         Cleo Abram  YXd4z3gWyVE
# 3         Cleo Abram  YXd4z3gWyVE
# 4         Cleo Abram  YXd4z3gWyVE
# ...              ...          ...
# 861957  Physics Girl  xyXpQxz7BOs
# 861958  Physics Girl  xyXpQxz7BOs
# 861959  Physics Girl  xyXpQxz7BOs
# 861960  Physics Girl  xyXpQxz7BOs
# 861961  Physics Girl  xyXpQxz7BOs
#
#                                          Comment (Actual)
# 0       zombie spider!! bomb the damn lab before it's ...
# 1       This is way less cool than it seems, spiders a...
# 2       Spiders see this and this is why they made the...
# 3                                      you looks pretty 😍
# 4       I can hear the hairs standing up on my wife’s ...
# ...                                                   ...
# 861957  hey girl,make more vdos and make it lengthy .....
# 861958                                              Third
# 861959                                              third
# 861960                                             Second
# 861961                                              first
#
# [861962 rows x 3 columns]

# %%
df1=data.copy()
df2=data.copy()
df3=data.copy()
df4=data.copy()
df1 = df1.loc[df1['User'] == 'Cleo Abram']
df2 = df2.loc[df2['User'] == 'Physics Girl']
df3 = df3.loc[df3['User'] == 'neo']
df4 = df4.loc[df4['User'] == 'Jet Lag: The Game']

data = pd.concat([df1,df4,df3,df2])
data
# Out:
#                 User     Video ID  \
# 0         Cleo Abram  YXd4z3gWyVE
# 1         Cleo Abram  YXd4z3gWyVE
# 2         Cleo Abram  YXd4z3gWyVE
# 3         Cleo Abram  YXd4z3gWyVE
# 4         Cleo Abram  YXd4z3gWyVE
# ...              ...          ...
# 861957  Physics Girl  xyXpQxz7BOs
# 861958  Physics Girl  xyXpQxz7BOs
# 861959  Physics Girl  xyXpQxz7BOs
# 861960  Physics Girl  xyXpQxz7BOs
# 861961  Physics Girl  xyXpQxz7BOs
#
#                                          Comment (Actual)
# 0       zombie spider!! bomb the damn lab before it's ...
# 1       This is way less cool than it seems, spiders a...
# 2       Spiders see this and this is why they made the...
# 3                                      you looks pretty 😍
# 4       I can hear the hairs standing up on my wife’s ...
# ...                                                   ...
# 861957  hey girl,make more vdos and make it lengthy .....
# 861958                                              Third
# 861959                                              third
# 861960                                             Second
# 861961                                              first
#
# [394469 rows x 3 columns]

# %%
data.describe()
# Out:
#                 User     Video ID Comment (Actual)
# count         394469       394469           379081
# unique             4          292           366927
# top     Physics Girl  6kARg-Use4Y          Thanks!
# freq          283267        15646              353

# %%
#No. of Comments of a particular Youtuber
fig,ax = plt.subplots()
data['User'].value_counts().plot(ax=ax, kind='bar', xlabel='Youtuber', ylabel='No. of comment on video')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(data['User'])
user_data = le.transform(data['User'])
data['User'] = user_data

le.fit(data['Video ID'])
video_ID = le.transform(data['Video ID'])
data['Video ID'] = video_ID

data
# Out:
#         User  Video ID                                   Comment (Actual)
# 0          0       153  zombie spider!! bomb the damn lab before it's ...
# 1          0       153  This is way less cool than it seems, spiders a...
# 2          0       153  Spiders see this and this is why they made the...
# 3          0       153                                 you looks pretty 😍
# 4          0       153  I can hear the hairs standing up on my wife’s ...
# ...      ...       ...                                                ...
# 861957     2       283  hey girl,make more vdos and make it lengthy .....
# 861958     2       283                                              Third
# 861959     2       283                                              third
# 861960     2       283                                             Second
# 861961     2       283                                              first
#
# [394469 rows x 3 columns]

# %%
data = data.dropna()
data
# Out:
#         User  Video ID                                   Comment (Actual)
# 0          0       153  zombie spider!! bomb the damn lab before it's ...
# 1          0       153  This is way less cool than it seems, spiders a...
# 2          0       153  Spiders see this and this is why they made the...
# 3          0       153                                 you looks pretty 😍
# 4          0       153  I can hear the hairs standing up on my wife’s ...
# ...      ...       ...                                                ...
# 861957     2       283  hey girl,make more vdos and make it lengthy .....
# 861958     2       283                                              Third
# 861959     2       283                                              third
# 861960     2       283                                             Second
# 861961     2       283                                              first
#
# [379081 rows x 3 columns]

# %%
data.isnull().sum()
# Out:
# User                0
# Video ID            0
# Comment (Actual)    0
# dtype: int64

# %%
import nltk
nltk.download('punkt')

# %%
#to find no. of words and sentences in the comments
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

data["num_sentences"] = data['Comment (Actual)'].apply(lambda x: len(sent_tokenize(x)))
data["num_words"] = data['Comment (Actual)'].apply(lambda x: len(word_tokenize(x)))

# %%
data
# Out:
#         User  Video ID                                   Comment (Actual)  \
# 0          0       153  zombie spider!! bomb the damn lab before it's ...
# 1          0       153  This is way less cool than it seems, spiders a...
# 2          0       153  Spiders see this and this is why they made the...
# 3          0       153                                 you looks pretty 😍
# 4          0       153  I can hear the hairs standing up on my wife’s ...
# ...      ...       ...                                                ...
# 861957     2       283  hey girl,make more vdos and make it lengthy .....
# 861958     2       283                                              Third
# 861959     2       283                                              third
# 861960     2       283                                             Second
# 861961     2       283                                              first
#
#         num_sentences  num_words
# 0                   3         14
# 1                   1         72
# 2                   2         26
# 3                   1          4
# 4                   1         18
# ...               ...        ...
# 861957              1         15
# 861958              1          1
# 861959              1          1
# 861960              1          1
# 861961              1          1
#
# [379081 rows x 5 columns]

# %%
#required libraries
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import silhouette_score

# %% [markdown]
# # **K Means Clustering**

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

# %%
from sklearn.cluster import KMeans

df1 = data.copy()

df1['New Comment (Actual)'] = df1['Comment (Actual)'].str.replace('[^a-zA-Z0-9\s]', '') # remove special characters
df1['New Comment (Actual)'] = df1['New Comment (Actual)'].str.lower()

tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_features = tfidf_vectorizer.fit_transform(df1['New Comment (Actual)'])

# Clustering using K-Means
kmeans = KMeans(n_clusters=2)
kmeans.fit(tfidf_features)
tfidf_cluster_labels = kmeans.labels_
df1["label"] = kmeans.labels_

spam_indices = [i for i, label in enumerate(tfidf_cluster_labels) if label == 1]
ham_indices = [i for i, label in enumerate(tfidf_cluster_labels) if label == 0]

df1= df1.drop(["New Comment (Actual)"],axis=1)

# %%
temp = {'Spam':len(spam_indices), 'Non Spam':len(ham_indices)}
Type = list(temp.keys())
Count = list(temp.values())

fig = plt.figure(figsize = (10, 5))
plt.bar(Type, Count, width = 0.4)

plt.xlabel("Type of Comment")
plt.ylabel("No. of Comment")
plt.title("clustering by K-Means Algorithm")
plt.show()

# %%
spam_comments = df1.iloc[spam_indices]
spam_comments
# Out:
#         User  Video ID                                   Comment (Actual)  \
# 106        0       153                                         Great! lol
# 146        0       132     terrible video terrible topic terrible society
# 169        0       132                 gorgeous and smart, great video :D
# 177        0       132  Can you cover the other cures for cancer that ...
# 183        0       132  that quality in the video call was so noticeable.
# ...      ...       ...                                                ...
# 861938     2       283  Thank you so much for making the video for us ...
# 861943     2       283         Wow I am really early! I love these video!
# 861947     2       283  Please make a future video explaining in a lit...
# 861950     2       283                          Amazing video!! Congrats!
# 861955     2       283                                       Nice video!!
#
#         num_sentences  num_words  label
# 106                 2          3      1
# 146                 1          6      1
# 169                 1          8      1
# 177                 3         55      1
# 183                 1         10      1
# ...               ...        ...    ...
# 861938              1         13      1
# 861943              2         11      1
# 861947              1         21      1
# 861950              2          6      1
# 861955              2          4      1
#
# [20036 rows x 6 columns]

# %%
ham_comments = df1.iloc[ham_indices]
ham_comments
# Out:
#         User  Video ID                                   Comment (Actual)  \
# 0          0       153  zombie spider!! bomb the damn lab before it's ...
# 1          0       153  This is way less cool than it seems, spiders a...
# 2          0       153  Spiders see this and this is why they made the...
# 3          0       153                                 you looks pretty 😍
# 4          0       153  I can hear the hairs standing up on my wife’s ...
# ...      ...       ...                                                ...
# 861957     2       283  hey girl,make more vdos and make it lengthy .....
# 861958     2       283                                              Third
# 861959     2       283                                              third
# 861960     2       283                                             Second
# 861961     2       283                                              first
#
#         num_sentences  num_words  label
# 0                   3         14      0
# 1                   1         72      0
# 2                   2         26      0
# 3                   1          4      0
# 4                   1         18      0
# ...               ...        ...    ...
# 861957              1         15      0
# 861958              1          1      0
# 861959              1          1      0
# 861960              1          1      0
# 861961              1          1      0
#
# [359045 rows x 6 columns]

# %%
df1
# Out:
#         User  Video ID                                   Comment (Actual)  \
# 0          0       153  zombie spider!! bomb the damn lab before it's ...
# 1          0       153  This is way less cool than it seems, spiders a...
# 2          0       153  Spiders see this and this is why they made the...
# 3          0       153                                 you looks pretty 😍
# 4          0       153  I can hear the hairs standing up on my wife’s ...
# ...      ...       ...                                                ...
# 861957     2       283  hey girl,make more vdos and make it lengthy .....
# 861958     2       283                                              Third
# 861959     2       283                                              third
# 861960     2       283                                             Second
# 861961     2       283                                              first
#
#         num_sentences  num_words  label
# 0                   3         14      0
# 1                   1         72      0
# 2                   2         26      0
# 3                   1          4      0
# 4                   1         18      0
# ...               ...        ...    ...
# 861957              1         15      0
# 861958              1          1      0
# 861959              1          1      0
# 861960              1          1      0
# 861961              1          1      0
#
# [379081 rows x 6 columns]

# %%
silhouette_score = silhouette_score(tfidf_features, kmeans.labels_)
print("Silhouette Score:", silhouette_score)
# Out:
# Silhouette Score: 0.005253983053248836

# %% [markdown]
# # **DBSCAN CLustering**

# %%
from sklearn.cluster import DBSCAN
from sklearn.feature_extraction.text import TfidfVectorizer

df2 = data.copy()
df2 = df2.iloc[:20000]

df2['New Comment (Actual)'] = df2['Comment (Actual)'].str.replace('[^a-zA-Z0-9\s]', '') # remove special characters
df2['New Comment (Actual)'] = df2['New Comment (Actual)'].str.lower()

vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(df2['New Comment (Actual)'])

# Cluster the comments using DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=75)
dbscan.fit(X)
dbscan_cluster_labels = dbscan.labels_
df2['label'] = dbscan.labels_

spam_indices = [i for i, label in enumerate(dbscan_cluster_labels) if label == 0]
ham_indices = [i for i, label in enumerate(dbscan_cluster_labels) if label == -1]

df2= df2.drop(["New Comment (Actual)"],axis=1)

# %%
dic = {'Spam':len(spam_indices), 'Non Spam':len(ham_indices)}
Type = list(dic.keys())
Count = list(dic.values())

fig = plt.figure(figsize = (10, 5))
plt.bar(Type, Count, width = 0.4)

plt.xlabel("Type of Comment")
plt.ylabel("No. of Comment")
plt.title("clustering by DBSCAN Algorithm")
plt.show()

# %%
spam_comments = df2.iloc[spam_indices]
spam_comments
# Out:
#        User  Video ID            Comment (Actual)  num_sentences  num_words  \
# 28        0       153                         😭😱🫥              1          1
# 34        0       153                        No ❤              1          2
# 56        0       153                         NO!              1          2
# 82        0       153                      😭😭😭😭😭😭              1          1
# 91        0       153                          NO              1          1
# ...     ...       ...                         ...            ...        ...
# 19528     0       124                     I am in              1          3
# 19642     0       124                         F y              1          2
# 19738     0       124                          ❤️              1          1
# 19740     0       124                           😎              1          1
# 19967     0       124  هذا أفضل فيديو على الإطلاق              1          5
#
#        label
# 28         0
# 34         0
# 56         0
# 82         0
# 91         0
# ...      ...
# 19528      0
# 19642      0
# 19738      0
# 19740      0
# 19967      0
#
# [172 rows x 6 columns]

# %%
ham_comments = df2.iloc[ham_indices]
ham_comments
# Out:
#        User  Video ID                                   Comment (Actual)  \
# 0         0       153  zombie spider!! bomb the damn lab before it's ...
# 1         0       153  This is way less cool than it seems, spiders a...
# 2         0       153  Spiders see this and this is why they made the...
# 3         0       153                                 you looks pretty 😍
# 4         0       153  I can hear the hairs standing up on my wife’s ...
# ...     ...       ...                                                ...
# 20012     0       124  I love when americans try to explain european ...
# 20013     0       124  Think F1 gonna be more profitable soon with mo...
# 20014     0       124  An advertisement for  mercedes by a less than ...
# 20015     0       124  As a long time F1 fan, this was a great intro ...
# 20016     0       124  yeah yeah yeah they should put all this energy...
#
#        num_sentences  num_words  label
# 0                  3         14     -1
# 1                  1         72     -1
# 2                  2         26     -1
# 3                  1          4     -1
# 4                  1         18     -1
# ...              ...        ...    ...
# 20012              1         48     -1
# 20013              1         13     -1
# 20014              2         13     -1
# 20015              1         17     -1
# 20016              1         21     -1
#
# [19707 rows x 6 columns]

# %%
df2
# Out:
#        User  Video ID                                   Comment (Actual)  \
# 0         0       153  zombie spider!! bomb the damn lab before it's ...
# 1         0       153  This is way less cool than it seems, spiders a...
# 2         0       153  Spiders see this and this is why they made the...
# 3         0       153                                 you looks pretty 😍
# 4         0       153  I can hear the hairs standing up on my wife’s ...
# ...     ...       ...                                                ...
# 20012     0       124  I love when americans try to explain european ...
# 20013     0       124  Think F1 gonna be more profitable soon with mo...
# 20014     0       124  An advertisement for  mercedes by a less than ...
# 20015     0       124  As a long time F1 fan, this was a great intro ...
# 20016     0       124  yeah yeah yeah they should put all this energy...
#
#        num_sentences  num_words  label
# 0                  3         14     -1
# 1                  1         72     -1
# 2                  2         26     -1
# 3                  1          4     -1
# 4                  1         18     -1
# ...              ...        ...    ...
# 20012              1         48     -1
# 20013              1         13     -1
# 20014              2         13     -1
# 20015              1         17     -1
# 20016              1         21     -1
#
# [20000 rows x 6 columns]

# %%
silhouette_score = silhouette_score(X, dbscan.labels_)
print("Silhouette Score:", silhouette_score)
# Out:
# Silhouette Score: -0.27168961202769176

# %% [markdown]
# # **Spectral Clustering**

# %%
from sklearn.cluster import SpectralClustering

df3 = data.copy()
df3 = df3[:20000]

df3['New Comment (Actual)'] = df3['Comment (Actual)'].str.replace('[^a-zA-Z0-9\s]', '') # remove special characters
df3['New Comment (Actual)'] = df3['New Comment (Actual)'].str.lower()

vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(df3['New Comment (Actual)'])

# Perform spectral clustering
n_clusters = 2
spectral = SpectralClustering(n_clusters=n_clusters, affinity='nearest_neighbors', n_jobs=-1)
spectral.fit(X)
spectral_cluster_labels = spectral.labels_
df3['label'] = spectral.labels_

spam_indices = [i for i, label in enumerate(spectral_cluster_labels) if label == 1]
ham_indices = [i for i, label in enumerate(spectral_cluster_labels) if label == 0]

df3= df3.drop(["New Comment (Actual)"],axis=1)

# %%
dic = {'Spam':len(spam_indices), 'Non Spam':len(ham_indices)}
Type = list(dic.keys())
Count = list(dic.values())

fig = plt.figure(figsize = (10, 5))
plt.bar(Type, Count, width = 0.4)

plt.xlabel("Type of Comment")
plt.ylabel("No. of Comment")
plt.title("clustering by Spectral Algorithm")
plt.show()

# %%
spam_comments = df3.iloc[spam_indices]
spam_comments
# Out:
#        User  Video ID                          Comment (Actual)  \
# 5287      0       123  The Waffle House has found it’s new host
# 5441      0       263   The waffle house has found its new host
# 5484      0       194   The waffle House has found its new host
# 5485      0       194   The waffle house has found its new host
# 5828      0        82  The waffle house has found its new host.
# ...     ...       ...                                       ...
# 14015     0       237   The Waffle House Has Found Its new host
# 14019     0       237   The waffle House has found its new host
# 14020     0       237  The waffle house has found it's new host
# 14022     0       237  The waffle house has found it's new host
# 14024     0       237   The Waffle House has found its new host
#
#        num_sentences  num_words  label
# 5287               1         10      1
# 5441               1          8      1
# 5484               1          8      1
# 5485               1          8      1
# 5828               1          9      1
# ...              ...        ...    ...
# 14015              1          8      1
# 14019              1          8      1
# 14020              1          9      1
# 14022              1          9      1
# 14024              1          8      1
#
# [132 rows x 6 columns]

# %%
ham_comments = df3.iloc[ham_indices]
ham_comments
# Out:
#        User  Video ID                                   Comment (Actual)  \
# 0         0       153  zombie spider!! bomb the damn lab before it's ...
# 1         0       153  This is way less cool than it seems, spiders a...
# 2         0       153  Spiders see this and this is why they made the...
# 3         0       153                                 you looks pretty 😍
# 4         0       153  I can hear the hairs standing up on my wife’s ...
# ...     ...       ...                                                ...
# 20012     0       124  I love when americans try to explain european ...
# 20013     0       124  Think F1 gonna be more profitable soon with mo...
# 20014     0       124  An advertisement for  mercedes by a less than ...
# 20015     0       124  As a long time F1 fan, this was a great intro ...
# 20016     0       124  yeah yeah yeah they should put all this energy...
#
#        num_sentences  num_words  label
# 0                  3         14      0
# 1                  1         72      0
# 2                  2         26      0
# 3                  1          4      0
# 4                  1         18      0
# ...              ...        ...    ...
# 20012              1         48      0
# 20013              1         13      0
# 20014              2         13      0
# 20015              1         17      0
# 20016              1         21      0
#
# [19868 rows x 6 columns]

# %%
df3
# Out:
#        User  Video ID                                   Comment (Actual)  \
# 0         0       153  zombie spider!! bomb the damn lab before it's ...
# 1         0       153  This is way less cool than it seems, spiders a...
# 2         0       153  Spiders see this and this is why they made the...
# 3         0       153                                 you looks pretty 😍
# 4         0       153  I can hear the hairs standing up on my wife’s ...
# ...     ...       ...                                                ...
# 20012     0       124  I love when americans try to explain european ...
# 20013     0       124  Think F1 gonna be more profitable soon with mo...
# 20014     0       124  An advertisement for  mercedes by a less than ...
# 20015     0       124  As a long time F1 fan, this was a great intro ...
# 20016     0       124  yeah yeah yeah they should put all this energy...
#
#        num_sentences  num_words  label
# 0                  3         14      0
# 1                  1         72      0
# 2                  2         26      0
# 3                  1          4      0
# 4                  1         18      0
# ...              ...        ...    ...
# 20012              1         48      0
# 20013              1         13      0
# 20014              2         13      0
# 20015              1         17      0
# 20016              1         21      0
#
# [20000 rows x 6 columns]

# %%
silhouette_score = silhouette_score(X, spectral.labels_)
print("Silhouette Score:", silhouette_score)
# Out:
# Silhouette Score: 0.010585267157676208

# %% [markdown]
# # **Hierarchical Clustering (Agglomerative)**

# %%
from sklearn.cluster import AgglomerativeClustering

df4 = data.copy()
df4 = df4.iloc[:5000]

df4['New Comment (Actual)'] = df4['Comment (Actual)'].str.replace('[^a-zA-Z0-9\s]', '') # remove special characters
df4['New Comment (Actual)'] = df4['New Comment (Actual)'].str.lower()

vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(df4['New Comment (Actual)'])

# Use Agglomerative Clustering to assign cluster labels
n_clusters = 2
agglo = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward')
agglo.fit(X.toarray())
agglo_cluster_labels = agglo.labels_
df4['label'] = agglo.labels_

spam_indices = [i for i, label in enumerate(agglo_cluster_labels) if label == 1]
ham_indices = [i for i, label in enumerate(agglo_cluster_labels) if label == 0]

df4= df4.drop(["New Comment (Actual)"],axis=1)

# %%
dic = {'Spam':len(spam_indices), 'Non Spam':len(ham_indices)}
Type = list(dic.keys())
Count = list(dic.values())

fig = plt.figure(figsize = (10, 5))
plt.bar(Type, Count, width = 0.4)

plt.xlabel("Type of Comment")
plt.ylabel("No. of Comment")
plt.title("clustering by Hierarchical (Agglomerative) Algorithm")
plt.show()

# %%
spam_comments = df4.iloc[spam_indices]
spam_comments
# Out:
#       User  Video ID                                   Comment (Actual)  \
# 2599     0        72                             What about formula E…?
# 2605     0        72                                          Formula E
# 2625     0        72                              What about formula E?
# 2770     0        72                         The already have Formula E
# 2771     0        72                          Formula E is here already
# 2817     0        72                                   See Formula E...
# 2819     0        72                                 FORMULA E.........
# 2946     0        72                                         Formula E?
# 3088     0        72                                 There is formula E
# 3137     0        72                                          Formula E
# 3140     0        72                         There is already Formula E
# 3179     0        72                        Formula E is already there.
# 3189     0        72                              We do have Formula E.
# 3208     0        72                                      ✨ Formula E ✨
# 3236     0        72                                          Formula E
# 3267     0        72                            There already formula E
# 3350     0        72  NO, We have Formula E for that. Formula 1 shou...
# 3385     0        72                       There is already a formula E
# 3391     0        72                    but there already is formula e?
# 3476     0        72                                         Formula E?
# 3639     0        72                                         Formula E?
# 3751     0        72                              What is Formula E 😂😂😂
# 3824     0        72                                          Formula e
# 4076     0        72                                          Formula E
# 4259     0        72                                          Formula E
# 4322     0        72                                 Formula E is there
# 4325     0        72                     F1 is never becoming formula e
# 4411     0        72                               There is a Formula E
# 4434     0        72                                        formula E??
# 4447     0        72                                    there formula e
# 4538     0        72                                          Formula E
# 4567     0        72                         Formula E is already there
#
#       num_sentences  num_words  label
# 2599              1          5      1
# 2605              1          2      1
# 2625              1          5      1
# 2770              1          5      1
# 2771              1          5      1
# 2817              1          4      1
# 2819              1          3      1
# 2946              1          3      1
# 3088              1          4      1
# 3137              1          2      1
# 3140              1          5      1
# 3179              1          6      1
# 3189              1          6      1
# 3208              1          4      1
# 3236              1          2      1
# 3267              1          4      1
# 3350              2         17      1
# 3385              1          6      1
# 3391              1          7      1
# 3476              1          3      1
# 3639              1          3      1
# 3751              1          5      1
# 3824              1          2      1
# 4076              1          2      1
# 4259              1          2      1
# 4322              1          4      1
# 4325              1          6      1
# 4411              1          5      1
# 4434              2          4      1
# 4447              1          3      1
# 4538              1          2      1
# 4567              1          5      1

# %%
ham_comments = df4.iloc[ham_indices]
ham_comments
# Out:
#       User  Video ID                                   Comment (Actual)  \
# 0        0       153  zombie spider!! bomb the damn lab before it's ...
# 1        0       153  This is way less cool than it seems, spiders a...
# 2        0       153  Spiders see this and this is why they made the...
# 3        0       153                                 you looks pretty 😍
# 4        0       153  I can hear the hairs standing up on my wife’s ...
# ...    ...       ...                                                ...
# 4995     0        36  Banning ICE (internal combustion engine) vehic...
# 4996     0        36                               Eggsistential. 1:17
# 4997     0        36  I'd love to know more about the tech in the "r...
# 4998     0        36  When formula e was born, there was this huge m...
# 4999     0        36  Excellent as always. So nice to feel time was ...
#
#       num_sentences  num_words  label
# 0                 3         14      0
# 1                 1         72      0
# 2                 2         26      0
# 3                 1          4      0
# 4                 1         18      0
# ...             ...        ...    ...
# 4995              6        170      0
# 4996              2          3      0
# 4997              1         23      0
# 4998              6        130      0
# 4999              2         16      0
#
# [4968 rows x 6 columns]

# %%
df4
# Out:
#       User  Video ID                                   Comment (Actual)  \
# 0        0       153  zombie spider!! bomb the damn lab before it's ...
# 1        0       153  This is way less cool than it seems, spiders a...
# 2        0       153  Spiders see this and this is why they made the...
# 3        0       153                                 you looks pretty 😍
# 4        0       153  I can hear the hairs standing up on my wife’s ...
# ...    ...       ...                                                ...
# 4995     0        36  Banning ICE (internal combustion engine) vehic...
# 4996     0        36                               Eggsistential. 1:17
# 4997     0        36  I'd love to know more about the tech in the "r...
# 4998     0        36  When formula e was born, there was this huge m...
# 4999     0        36  Excellent as always. So nice to feel time was ...
#
#       num_sentences  num_words  label
# 0                 3         14      0
# 1                 1         72      0
# 2                 2         26      0
# 3                 1          4      0
# 4                 1         18      0
# ...             ...        ...    ...
# 4995              6        170      0
# 4996              2          3      0
# 4997              1         23      0
# 4998              6        130      0
# 4999              2         16      0
#
# [5000 rows x 6 columns]

# %%
silhouette_score = silhouette_score(X, agglo.labels_)
print("Silhouette Score:", silhouette_score)
# Out:
# Silhouette Score: -0.0022603960832925122
